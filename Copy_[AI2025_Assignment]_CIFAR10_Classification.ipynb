# %% [markdown]
# <a href="https://colab.research.google.com/github/sorsalaura-hue/AI_Assignment_1/blob/main/Copy_%5BAI2025_Assignment%5D_CIFAR10_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR10 Classification

# %% [markdown]
# ## Import Packages

# %%
import sys
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Preparation
# Use CIFAR10 handwriting dataset

# %%
cifar10 = tf.keras.datasets.cifar10

# %% [markdown]
# Prepare data for training

# %%
# train / test split
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# minmax normalization
x_train, x_test = x_train / 255.0, x_test / 255.0

# one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step

# %% [markdown]
# # Compile and Train neural network

# %% [markdown]
# ## CNN Modeling
# Create a convolutional neural network

# %% [markdown]
# ### Goal
#
# Improve the provided basic CNN model and achieve CIFAR-10 **test accuracy ≥ 75%**.

# %% [markdown]
# Modify the network architecture!

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(32, 32, 3)),

    tf.keras.layers.Conv2D(64, 3, padding="same", activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(64, 3, padding="same", activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(0.25),

    tf.keras.layers.Conv2D(256, 3, padding="same", activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Dropout(0.25),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(512, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(10, activation="softmax")
])

# %% [markdown]
# # Compile and Train neural network

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
history = model.fit(
    x_train, y_train,
    epochs=30,
    batch_size=64,
    validation_split=0.1

)
# Out:
# Epoch 1/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 25s 23ms/step - accuracy: 0.4331 - loss: 1.8111 - val_accuracy: 0.6194 - val_loss: 1.0703
# Epoch 2/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.6629 - loss: 0.9627 - val_accuracy: 0.6956 - val_loss: 0.8930
# Epoch 3/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7173 - loss: 0.7962 - val_accuracy: 0.7210 - val_loss: 0.8126
# Epoch 4/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7669 - loss: 0.6750 - val_accuracy: 0.6484 - val_loss: 1.1237
# Epoch 5/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7938 - loss: 0.5951 - val_accuracy: 0.7196 - val_loss: 0.9735
# Epoch 6/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8211 - loss: 0.5128 - val_accuracy: 0.7714 - val_loss: 0.6933
# Epoch 7/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8424 - loss: 0.4487 - val_accuracy: 0.7624 - val_loss: 0.7303
# Epoch 8/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8688 - loss: 0.3742 - val_accuracy: 0.4732 - val_loss: 2.6577
# Epoch 9/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8764 - loss: 0.3501 - val_accuracy: 0.7898 - val_loss: 0.6944
# Epoch 10/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.8940 - loss: 0.2984 - val_accuracy: 0.7802 - val_loss: 0.7349
# Epoch 11/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9113 - loss: 0.2479 - val_accuracy: 0.7864 - val_loss: 0.7088
# Epoch 12/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9128 - loss: 0.2413 - val_accuracy: 0.7890 - val_loss: 0.7308
# Epoch 13/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9251 - loss: 0.2095 - val_accuracy: 0.7766 - val_loss: 0.7953
# Epoch 14/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9333 - loss: 0.1899 - val_accuracy: 0.7934 - val_loss: 0.7745
# Epoch 15/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9349 - loss: 0.1841 - val_accuracy: 0.7942 - val_loss: 0.7585
# Epoch 16/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9380 - loss: 0.1749 - val_accuracy: 0.8152 - val_loss: 0.6915
# Epoch 17/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9472 - loss: 0.1466 - val_accuracy: 0.7946 - val_loss: 0.7848
# Epoch 18/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9513 - loss: 0.1369 - val_accuracy: 0.7990 - val_loss: 0.7814
# Epoch 19/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9501 - loss: 0.1436 - val_accuracy: 0.8020 - val_loss: 0.8060
# Epoch 20/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9510 - loss: 0.1331 - val_accuracy: 0.8016 - val_loss: 0.7528
# Epoch 21/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9547 - loss: 0.1296 - val_accuracy: 0.8104 - val_loss: 0.7487
# Epoch 22/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9559 - loss: 0.1248 - val_accuracy: 0.8122 - val_loss: 0.7339
# Epoch 23/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9617 - loss: 0.1065 - val_accuracy: 0.8026 - val_loss: 0.7940
# Epoch 24/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9603 - loss: 0.1150 - val_accuracy: 0.8158 - val_loss: 0.7297
# Epoch 25/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9464 - loss: 0.1573 - val_accuracy: 0.8184 - val_loss: 0.7004
# Epoch 26/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9630 - loss: 0.1089 - val_accuracy: 0.8170 - val_loss: 0.6844
# Epoch 27/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9609 - loss: 0.1070 - val_accuracy: 0.8206 - val_loss: 0.7741
# Epoch 28/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9683 - loss: 0.0933 - val_accuracy: 0.8060 - val_loss: 0.7640
# Epoch 29/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9691 - loss: 0.0894 - val_accuracy: 0.8152 - val_loss: 0.7920
# Epoch 30/30
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9701 - loss: 0.0912 - val_accuracy: 0.8122 - val_loss: 0.8091

# %% [markdown]
# ## Evaluate neural network performance

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 2s - 8ms/step - accuracy: 0.8050 - loss: 0.8353
# [0.8352515697479248, 0.8050000071525574]

# %%
prob = model.predict(x_test[0:40], verbose=0)
pred = tf.argmax(prob, axis=1)

fig = plt.figure(figsize=(12, 18))
for i in range(40):
    subplot = fig.add_subplot(8, 5, i + 1)
    subplot.set_xticks([])
    subplot.set_yticks([])
    string = r'$\hat{y}$'
    subplot.set_title(f'$y$:{tf.argmax(y_test[i])}, {string}:{pred[i].numpy()}')
    subplot.imshow(tf.squeeze(x_test[i]))
plt.show()
true_label = tf.argmax(y_test[i]).numpy()
pred_label = pred[i].numpy()
plt.title(f"GT: {true_label}, Pred: {pred_label}")
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.8050000071525574
